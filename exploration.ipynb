# %%
import pandas as pd
import numpy as np

# %%
population_data = pd.read_csv("data/population.csv")
population_data.head()
# Out:
#    Year  District.Code District.Name  Neighborhood.Code  \
# 0  2017              1  Ciutat Vella                  1
# 1  2017              1  Ciutat Vella                  2
# 2  2017              1  Ciutat Vella                  3
# 3  2017              1  Ciutat Vella                  4
# 4  2017              2      Eixample                  5
#
#                        Neighborhood.Name Gender  Age  Number
# 0                               el Raval   Male  0-4     224
# 1                         el Barri Gòtic   Male  0-4      50
# 2                         la Barceloneta   Male  0-4      43
# 3  Sant Pere, Santa Caterina i la Ribera   Male  0-4      95
# 4                          el Fort Pienc   Male  0-4     124

# %%
#Renaming columns 
popul_data = population_data.rename(columns={"District.Code": "DistrictCode","District.Name": "DistrictName","Neighborhood.Code": "NeighborhoodCode", "Neighborhood.Name":"NeighborhoodName"})
popul_data
# Out:
#        Year  DistrictCode         DistrictName  NeighborhoodCode  \
# 0      2017             1         Ciutat Vella                 1
# 1      2017             1         Ciutat Vella                 2
# 2      2017             1         Ciutat Vella                 3
# 3      2017             1         Ciutat Vella                 4
# 4      2017             2             Eixample                 5
# 5      2017             2             Eixample                 6
# 6      2017             2             Eixample                 7
# 7      2017             2             Eixample                 8
# 8      2017             2             Eixample                 9
# 9      2017             2             Eixample                10
# 10     2017             3       Sants-Montjuïc                11
# 11     2017             3       Sants-Montjuïc                12
# 12     2017             3       Sants-Montjuïc                13
# ...

# %%
popul_data.DistrictName.unique()
# Out:
# array(['Ciutat Vella', 'Eixample', 'Sants-Montjuïc', 'Les Corts',
#        'Sarrià-Sant Gervasi', 'Gràcia', 'Horta-Guinardó', 'Nou Barris',
#        'Sant Andreu', 'Sant Martí'], dtype=object)

# %%
popul_data.sample()
# Out:
#        Year  DistrictCode    DistrictName  NeighborhoodCode  \
# 59822  2013             7  Horta-Guinardó                36
#
#            NeighborhoodName Gender    Age  Number
# 59822  la Font d'en Fargues   Male  50-54      58

# %%
popul_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70080 entries, 0 to 70079
# Data columns (total 8 columns):
# Year                70080 non-null int64
# DistrictCode        70080 non-null int64
# DistrictName        70080 non-null object
# NeighborhoodCode    70080 non-null int64
# NeighborhoodName    70080 non-null object
# Gender              70080 non-null object
# Age                 70080 non-null object
# Number              70080 non-null int64
# dtypes: int64(4), object(4)
# memory usage: 4.3+ MB

# %%
popul_data.columns
# Out:
# Index(['Year', 'DistrictCode', 'DistrictName', 'NeighborhoodCode',
#        'NeighborhoodName', 'Gender', 'Age', 'Number'],
#       dtype='object')

# %%
popul_data.isnull().sum()
# Out:
# Year                0
# DistrictCode        0
# DistrictName        0
# NeighborhoodCode    0
# NeighborhoodName    0
# Gender              0
# Age                 0
# Number              0
# dtype: int64

# %%
popul_data.index
# Out:
# RangeIndex(start=0, stop=70080, step=1)

# %%
popul_data.shape
# Out:
# (70080, 8)

# %%
popul_data.describe()
# Out:
#                Year  DistrictCode  NeighborhoodCode        Number
# count  70080.000000  70080.000000      70080.000000  70080.000000
# mean    2015.000000      6.246575         37.000000    114.844720
# std        1.414224      2.788356         21.071458     96.540389
# min     2013.000000      1.000000          1.000000      0.000000
# 25%     2014.000000      4.000000         19.000000     43.000000
# 50%     2015.000000      7.000000         37.000000     92.000000
# 75%     2016.000000      8.000000         55.000000    162.000000
# max     2017.000000     10.000000         73.000000    777.000000

# %%
popul_data.dtypes
# Out:
# Year                 int64
# DistrictCode         int64
# DistrictName        object
# NeighborhoodCode     int64
# NeighborhoodName    object
# Gender              object
# Age                 object
# Number               int64
# dtype: object

# %%
popul_data.Number.sum()
# Out:
# 8048318

# %%
(popul_data.groupby(["DistrictName", "Year"])["Number"].sum()).to_frame()
# Out:
#                           Number
# DistrictName        Year
# Ciutat Vella        2013  103339
#                     2014  100685
#                     2015  100115
#                     2016  100070
#                     2017  101387
# Eixample            2013  264780
#                     2014  263565
#                     2015  263558
#                     2016  264305
#                     2017  266416
# Gràcia              2013  120949
#                     2014  120273
#                     2015  120401
#                     2016  120918
#                     2017  121347
# Horta-Guinardó      2013  167743
#                     2014  166950
#                     2015  166559
#                     2016  167268
#                     2017  168751
# Les Corts           2013   81640
#                     2014   81200
#                     2015   81530
#                     2016   81642
#                     2017   82033
# Nou Barris          2013  165748
# ...

# %%
(popul_data.groupby(["DistrictCode","DistrictName", "Year"])["Number"].sum()).to_frame()
# Out:
#                                        Number
# DistrictCode DistrictName        Year
# 1            Ciutat Vella        2013  103339
#                                  2014  100685
#                                  2015  100115
#                                  2016  100070
#                                  2017  101387
# 2            Eixample            2013  264780
#                                  2014  263565
#                                  2015  263558
#                                  2016  264305
#                                  2017  266416
# 3            Sants-Montjuïc      2013  182685
#                                  2014  180824
#                                  2015  180757
#                                  2016  180977
#                                  2017  181910
# 4            Les Corts           2013   81640
#                                  2014   81200
#                                  2015   81530
#                                  2016   81642
# ...

# %%
(popul_data.groupby(["Gender","Year"])["Number"].sum()).to_frame()
# Out:
#              Number
# Gender Year
# Female 2013  848121
#        2014  844070
#        2015  845035
#        2016  847259
#        2017  854184
# Male   2013  763701
#        2014  758316
#        2015  759520
#        2016  761487
#        2017  766625

# %%
(popul_data.groupby(["Age","Year"])["Number"].sum()).to_frame()
# Out:
#             Number
# Age   Year
# 0-4   2013   69267
#       2014   68901
#       2015   68661
#       2016   68286
#       2017   68402
# 10-14 2013   62566
#       2014   63599
#       2015   64632
#       2016   65584
#       2017   67575
# 15-19 2013   63540
#       2014   62792
#       2015   63436
#       2016   64613
#       2017   65953
# 20-24 2013   78485
#       2014   76521
#       2015   76575
#       2016   77442
#       2017   79062
# 25-29 2013  110563
#       2014  105152
#       2015  103101
#       2016  103320
#       2017  106489
# 30-34 2013  138330
#       2014  131846
#       2015  127772
#       2016  123597
#       2017  122353
# ...            ...
# 70-74 2013   66101
#       2014   69372
#       2015   75221
#       2016   75465
#       2017   77501
# 75-79 2013   70531
#       2014   66453
#       2015   60913
#       2016   62026
#       2017   59962
# 80-84 2013   59803
#       2014   60484
#       2015   60599
#       2016   59776
#       2017   59453
# ...

# %%
(popul_data.groupby(["Age","Year","Gender"])["Number"].sum()).to_frame()
# Out:
#                    Number
# Age   Year Gender
# 0-4   2013 Female   33548
#            Male     35719
#       2014 Female   33510
#            Male     35391
#       2015 Female   33425
#            Male     35236
#       2016 Female   33205
#            Male     35081
#       2017 Female   33328
#            Male     35074
# 10-14 2013 Female   30513
#            Male     32053
#       2014 Female   31040
#            Male     32559
#       2015 Female   31482
#            Male     33150
#       2016 Female   32076
#            Male     33508
#       2017 Female   33064
#            Male     34511
# 15-19 2013 Female   30732
#            Male     32808
#       2014 Female   30309
#            Male     32483
#       2015 Female   30657
#            Male     32779
#       2016 Female   31149
#            Male     33464
#       2017 Female   31950
#            Male     34003
# ...                   ...
# 85-89 2013 Female   26185
#            Male     11887
#       2014 Female   26485
# ...

# %%
(popul_data.groupby(["DistrictCode","DistrictName","Year"])["Number"].sum()).to_frame()
# Out:
#                                        Number
# DistrictCode DistrictName        Year
# 1            Ciutat Vella        2013  103339
#                                  2014  100685
#                                  2015  100115
#                                  2016  100070
#                                  2017  101387
# 2            Eixample            2013  264780
#                                  2014  263565
#                                  2015  263558
#                                  2016  264305
#                                  2017  266416
# 3            Sants-Montjuïc      2013  182685
#                                  2014  180824
#                                  2015  180757
#                                  2016  180977
#                                  2017  181910
# 4            Les Corts           2013   81640
#                                  2014   81200
#                                  2015   81530
#                                  2016   81642
# ...

# %%
(popul_data.groupby(["DistrictName","NeighborhoodName","Year"])["Number"].sum()).to_frame()
# Out:
#                                                                 Number
# DistrictName        NeighborhoodName                      Year
# Ciutat Vella        Sant Pere, Santa Caterina i la Ribera 2013   22769
#                                                           2014   22358
#                                                           2015   22457
#                                                           2016   22306
#                                                           2017   22721
#                     el Barri Gòtic                        2013   16267
#                                                           2014   15734
#                                                           2015   15484
#                                                           2016   15614
#                                                           2017   16062
#                     el Raval                              2013   48800
# ...

# %%
(popul_data.groupby(["DistrictCode","DistrictName","Year","Gender"])["Number"].sum()).to_frame()
# Out:
#                                          Number
# DistrictCode DistrictName   Year Gender
# 1            Ciutat Vella   2013 Female   48836
#                                  Male     54503
#                             2014 Female   47878
#                                  Male     52807
#                             2015 Female   47579
#                                  Male     52536
#                             2016 Female   47633
#                                  Male     52437
#                             2017 Female   48467
#                                  Male     52920
# 2            Eixample       2013 Female  142614
#                                  Male    122166
#                             2014 Female  141589
#                                  Male    121976
#                             2015 Female  141341
#                                  Male    122217
#                             2016 Female  141539
#                                  Male    122766
# ...

# %%
(popul_data.groupby(["DistrictCode","DistrictName","NeighborhoodCode","NeighborhoodName","Year","Gender"])["Number"].sum()).to_frame()
# Out:
#                                                                                  Number
# DistrictCode DistrictName NeighborhoodCode NeighborhoodName         Year Gender
# 1            Ciutat Vella 1                el Raval                 2013 Female   22095
#                                                                          Male     26705
#                                                                     2014 Female   21643
#                                                                          Male     25846
#                                                                     2015 Female   21453
#                                                                          Male     25689
#                                                                     2016 Female   21379
#                                                                          Male     25750
#                                                                     2017 Female   21806
# ...

# %%
(popul_data.groupby("Year")["Number"].sum()).to_frame()
# Out:
#        Number
# Year
# 2013  1611822
# 2014  1602386
# 2015  1604555
# 2016  1608746
# 2017  1620809

# %%
(popul_data.groupby(["Year","Gender"])["Number"].sum()).to_frame()
# Out:
#              Number
# Year Gender
# 2013 Female  848121
#      Male    763701
# 2014 Female  844070
#      Male    758316
# 2015 Female  845035
#      Male    759520
# 2016 Female  847259
#      Male    761487
# 2017 Female  854184
#      Male    766625

# %%
(popul_data.groupby(["Year","DistrictName"])["Number"].sum()).to_frame()
# Out:
#                           Number
# Year DistrictName
# 2013 Ciutat Vella         103339
#      Eixample             264780
#      Gràcia               120949
#      Horta-Guinardó       167743
#      Les Corts             81640
#      Nou Barris           165748
#      Sant Andreu          146846
#      Sant Martí           232826
#      Sants-Montjuïc       182685
#      Sarrià-Sant Gervasi  145266
# 2014 Ciutat Vella         100685
#      Eixample             263565
#      Gràcia               120273
#      Horta-Guinardó       166950
#      Les Corts             81200
#      Nou Barris           164516
#      Sant Andreu          145983
#      Sant Martí           232629
#      Sants-Montjuïc       180824
#      Sarrià-Sant Gervasi  145761
# 2015 Ciutat Vella         100115
#      Eixample             263558
#      Gràcia               120401
#      Horta-Guinardó       166559
#      Les Corts             81530
#      Nou Barris           164648
#      Sant Andreu          146494
# ...
