# %%
import pandas as pd
import numpy as np

# %%
population_data = pd.read_csv("data/population.csv")
population_data.head()
# Out:
#    Year  District.Code District.Name  Neighborhood.Code  \
# 0  2017              1  Ciutat Vella                  1
# 1  2017              1  Ciutat Vella                  2
# 2  2017              1  Ciutat Vella                  3
# 3  2017              1  Ciutat Vella                  4
# 4  2017              2      Eixample                  5
#
#                        Neighborhood.Name Gender  Age  Number
# 0                               el Raval   Male  0-4     224
# 1                         el Barri Gòtic   Male  0-4      50
# 2                         la Barceloneta   Male  0-4      43
# 3  Sant Pere, Santa Caterina i la Ribera   Male  0-4      95
# 4                          el Fort Pienc   Male  0-4     124

# %%
#Renaming columns 
popul_data = population_data.rename(columns={"District.Code": "DistrictCode","District.Name": "DistrictName","Neighborhood.Code": "NeighborhoodCode", "Neighborhood.Name":"NeighborhoodName"})
popul_data
# Out:
#        Year  DistrictCode         DistrictName  NeighborhoodCode  \
# 0      2017             1         Ciutat Vella                 1
# 1      2017             1         Ciutat Vella                 2
# 2      2017             1         Ciutat Vella                 3
# 3      2017             1         Ciutat Vella                 4
# 4      2017             2             Eixample                 5
# 5      2017             2             Eixample                 6
# 6      2017             2             Eixample                 7
# 7      2017             2             Eixample                 8
# 8      2017             2             Eixample                 9
# 9      2017             2             Eixample                10
# 10     2017             3       Sants-Montjuïc                11
# 11     2017             3       Sants-Montjuïc                12
# 12     2017             3       Sants-Montjuïc                13
# ...

# %%
popul_data.DistrictName.unique()
# Out:
# array(['Ciutat Vella', 'Eixample', 'Sants-Montjuïc', 'Les Corts',
#        'Sarrià-Sant Gervasi', 'Gràcia', 'Horta-Guinardó', 'Nou Barris',
#        'Sant Andreu', 'Sant Martí'], dtype=object)

# %%
popul_data.sample()
# Out:
#        Year  DistrictCode DistrictName  NeighborhoodCode NeighborhoodName  \
# 46990  2014             8   Nou Barris                52   la Prosperitat
#
#       Gender    Age  Number
# 46990   Male  65-69     146

# %%
popul_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70080 entries, 0 to 70079
# Data columns (total 8 columns):
# Year                70080 non-null int64
# DistrictCode        70080 non-null int64
# DistrictName        70080 non-null object
# NeighborhoodCode    70080 non-null int64
# NeighborhoodName    70080 non-null object
# Gender              70080 non-null object
# Age                 70080 non-null object
# Number              70080 non-null int64
# dtypes: int64(4), object(4)
# memory usage: 4.3+ MB

# %%
popul_data.columns
# Out:
# Index(['Year', 'DistrictCode', 'DistrictName', 'NeighborhoodCode',
#        'NeighborhoodName', 'Gender', 'Age', 'Number'],
#       dtype='object')

# %%
popul_data.isnull().sum()
# Out:
# Year                0
# DistrictCode        0
# DistrictName        0
# NeighborhoodCode    0
# NeighborhoodName    0
# Gender              0
# Age                 0
# Number              0
# dtype: int64

# %%
popul_data.index
# Out:
# RangeIndex(start=0, stop=70080, step=1)

# %%
popul_data.shape
# Out:
# (70080, 8)

# %%
popul_data.describe()
# Out:
#                Year  DistrictCode  NeighborhoodCode        Number
# count  70080.000000  70080.000000      70080.000000  70080.000000
# mean    2015.000000      6.246575         37.000000    114.844720
# std        1.414224      2.788356         21.071458     96.540389
# min     2013.000000      1.000000          1.000000      0.000000
# 25%     2014.000000      4.000000         19.000000     43.000000
# 50%     2015.000000      7.000000         37.000000     92.000000
# 75%     2016.000000      8.000000         55.000000    162.000000
# max     2017.000000     10.000000         73.000000    777.000000

# %%
popul_data.dtypes
# Out:
# Year                 int64
# DistrictCode         int64
# DistrictName        object
# NeighborhoodCode     int64
# NeighborhoodName    object
# Gender              object
# Age                 object
# Number               int64
# dtype: object

# %%
popul_data.Number.sum()
# Out:
# 8048318

# %%
(popul_data.groupby("DistrictName")["Number"].sum()).to_frame().reset_index()
# Out:
#           DistrictName   Number
# 0         Ciutat Vella   505596
# 1             Eixample  1322624
# 2               Gràcia   603888
# 3       Horta-Guinardó   837271
# 4            Les Corts   408045
# 5           Nou Barris   826372
# 6          Sant Andreu   733648
# 7           Sant Martí  1168555
# 8       Sants-Montjuïc   907153
# 9  Sarrià-Sant Gervasi   735166

# %%
(popul_data.groupby("Gender")["Number"].sum()).to_frame().reset_index()
# Out:
#    Gender   Number
# 0  Female  4238669
# 1    Male  3809649

# %%
(popul_data.groupby("Age")["Number"].sum()).to_frame().reset_index()
# Out:
#       Age  Number
# 0     0-4  343517
# 1   10-14  323956
# 2   15-19  320334
# 3   20-24  388085
# 4   25-29  528625
# 5   30-34  643898
# 6   35-39  695727
# 7   40-44  646874
# 8   45-49  587788
# 9     5-9  342661
# 10  50-54  550379
# 11  55-59  498789
# 12  60-64  449216
# 13  65-69  436198
# 14  70-74  363660
# 15  75-79  319885
# 16  80-84  300115
# 17  85-89  197926
# 18  90-94   86740
# 19   >=95   23945

# %%
(popul_data.groupby(["Gender","Age"])["Number"].sum()).to_frame()
# Out:
#               Number
# Gender Age
# Female 0-4    167016
#        10-14  158175
#        15-19  154797
#        20-24  193809
#        25-29  271307
#        30-34  322712
#        35-39  341078
#        40-44  319783
#        45-49  298630
#        5-9    166539
#        50-54  289003
#        55-59  268292
#        60-64  246157
#        65-69  242338
#        70-74  205113
#        75-79  188774
#        80-84  187583
#        85-89  134039
#        90-94   64167
#        >=95    19357
# Male   0-4    176501
#        10-14  165781
#        15-19  165537
#        20-24  194276
#        25-29  257318
#        30-34  321186
#        35-39  354649
#        40-44  327091
#        45-49  289158
#        5-9    176122
#        50-54  261376
#        55-59  230497
#        60-64  203059
#        65-69  193860
#        70-74  158547
#        75-79  131111
#        80-84  112532
#        85-89   63887
#        90-94   22573
#        >=95     4588

# %%
(popul_data.groupby(["DistrictCode","DistrictName"])["Number"].sum()).to_frame().reset_index()
# Out:
#    DistrictCode         DistrictName   Number
# 0             1         Ciutat Vella   505596
# 1             2             Eixample  1322624
# 2             3       Sants-Montjuïc   907153
# 3             4            Les Corts   408045
# 4             5  Sarrià-Sant Gervasi   735166
# 5             6               Gràcia   603888
# 6             7       Horta-Guinardó   837271
# 7             8           Nou Barris   826372
# 8             9          Sant Andreu   733648
# 9            10           Sant Martí  1168555

# %%
(popul_data.groupby(["DistrictCode","DistrictName","NeighborhoodCode","NeighborhoodName"])["Number"].sum()).to_frame()
# Out:
#                                                                                                 Number
# DistrictCode DistrictName        NeighborhoodCode NeighborhoodName
# 1            Ciutat Vella        1                el Raval                                      238168
#                                  2                el Barri Gòtic                                 79161
#                                  3                la Barceloneta                                 75656
#                                  4                Sant Pere, Santa Caterina i la Ribera         112611
# 2            Eixample            5                el Fort Pienc                                 158444
#                                  6                la Sagrada Família                            257063
#                                  7                la Dreta de l'Eixample                        217976
# ...

# %%
(popul_data.groupby(["DistrictCode","DistrictName","Gender"])["Number"].sum()).to_frame()
# Out:
#                                          Number
# DistrictCode DistrictName        Gender
# 1            Ciutat Vella        Female  240393
#                                  Male    265203
# 2            Eixample            Female  709637
#                                  Male    612987
# 3            Sants-Montjuïc      Female  472988
#                                  Male    434165
# 4            Les Corts           Female  217859
#                                  Male    190186
# 5            Sarrià-Sant Gervasi Female  398621
#                                  Male    336545
# 6            Gràcia              Female  327386
#                                  Male    276502
# 7            Horta-Guinardó      Female  443771
#                                  Male    393500
# 8            Nou Barris          Female  436642
#                                  Male    389730
# 9            Sant Andreu         Female  385474
#                                  Male    348174
# ...

# %%
(popul_data.groupby(["DistrictCode","DistrictName","NeighborhoodCode","NeighborhoodName","Gender"])["Number"].sum()).to_frame()
# Out:
#                                                                                                   Number
# DistrictCode DistrictName   NeighborhoodCode NeighborhoodName                             Gender
# 1            Ciutat Vella   1                el Raval                                     Female  108376
#                                                                                           Male    129792
#                             2                el Barri Gòtic                               Female   37580
#                                                                                           Male     41581
#                             3                la Barceloneta                               Female   37943
#                                                                                           Male     37713
#                             4                Sant Pere, Santa Caterina i la Ribera        Female   56494
# ...
